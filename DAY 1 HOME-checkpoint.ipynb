# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('home_data.csv')
data
# Out:
#      beds  baths  size  zip_code    price
# 0       3    2.5  2590     98144   795000
# 1       4    2.0  2240     98106   915000
# 2       4    3.0  2040     98107   950000
# 3       4    3.0  3800     98199  1950000
# 4       2    2.0  1042     98102   950000
# ..    ...    ...   ...       ...      ...
# 415     4    3.0  3120     98144  1670000
# 416     3    2.0  1870     98136   849000
# 417     4    3.5  2285     98116  1500000
# 418     3    2.5  2783     98199  1640000
# 419     4    2.0  2540     98107  1280000
#
# [420 rows x 5 columns]

# %%
data=pd.read_csv('home_data.csv')
data
# Out:
#      beds  baths  size  zip_code    price
# 0       3    2.5  2590     98144   795000
# 1       4    2.0  2240     98106   915000
# 2       4    3.0  2040     98107   950000
# 3       4    3.0  3800     98199  1950000
# 4       2    2.0  1042     98102   950000
# ..    ...    ...   ...       ...      ...
# 415     4    3.0  3120     98144  1670000
# 416     3    2.0  1870     98136   849000
# 417     4    3.5  2285     98116  1500000
# 418     3    2.5  2783     98199  1640000
# 419     4    2.0  2540     98107  1280000
#
# [420 rows x 5 columns]

# %%
data.head()
# Out:
#    beds  baths  size  zip_code    price
# 0     3    2.5  2590     98144   795000
# 1     4    2.0  2240     98106   915000
# 2     4    3.0  2040     98107   950000
# 3     4    3.0  3800     98199  1950000
# 4     2    2.0  1042     98102   950000

# %% [markdown]
# # 2.)Explore and clean the data.Handle missing values and outliers.

# %%
data.tail()
# Out:
#      beds  baths  size  zip_code    price
# 415     4    3.0  3120     98144  1670000
# 416     3    2.0  1870     98136   849000
# 417     4    3.5  2285     98116  1500000
# 418     3    2.5  2783     98199  1640000
# 419     4    2.0  2540     98107  1280000

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'beds'}>,
#         <Axes: title={'center': 'baths'}>],
#        [<Axes: title={'center': 'size'}>,
#         <Axes: title={'center': 'zip_code'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: >]], dtype=object)

# %%
data.describe()
# Out:
#              beds       baths          size      zip_code         price
# count  420.000000  420.000000    420.000000    420.000000  4.200000e+02
# mean     3.000000    2.251190   1841.864286  98125.371429  9.694295e+05
# std      1.355621    1.034892   1008.702748     24.929976  5.763080e+05
# min      1.000000    0.500000    376.000000  98101.000000  1.594880e+05
# 25%      2.000000    1.500000   1120.000000  98107.000000  6.150000e+05
# 50%      3.000000    2.000000   1695.000000  98117.000000  8.450000e+05
# 75%      4.000000    3.000000   2370.000000  98133.000000  1.148500e+06
# max     15.000000    8.500000  11010.000000  98199.000000  5.495000e+06

# %%
data.head(10)
# Out:
#    beds  baths  size  zip_code    price
# 0     3    2.5  2590     98144   795000
# 1     4    2.0  2240     98106   915000
# 2     4    3.0  2040     98107   950000
# 3     4    3.0  3800     98199  1950000
# 4     2    2.0  1042     98102   950000
# 5     2    2.0  1190     98107   740000
# 6     1    1.0   670     98133   460000
# 7     5    3.5  4510     98105  3150000
# 8     3    2.5  1520     98108   565000
# 9     4    2.0  2340     98178   699000

# %%
data.isnull().sum()
# Out:
# beds        0
# baths       0
# size        0
# zip_code    0
# price       0
# dtype: int64

# %% [markdown]
# # 3.) Split the dataset into training and testing sets

# %%
a=data.iloc[:,:1]
a.head(20)
# Out:
#     beds
# 0      3
# 1      4
# 2      4
# 3      4
# 4      2
# 5      2
# 6      1
# 7      5
# 8      3
# 9      4
# 10     3
# 11     3
# 12     3
# 13     4
# 14     5
# 15     2
# 16     3
# 17     1
# 18     3
# 19     4

# %%
b=data.iloc[:,1:2]
b.head(20)
# Out:
#     baths
# 0     2.5
# 1     2.0
# 2     3.0
# 3     3.0
# 4     2.0
# 5     2.0
# 6     1.0
# 7     3.5
# 8     2.5
# 9     2.0
# 10    2.0
# 11    2.0
# 12    2.5
# 13    3.0
# 14    1.5
# 15    1.5
# 16    3.5
# 17    1.0
# 18    2.5
# 19    3.5

# %%
c=data.iloc[:,2:3]
c.tail(10)
# Out:
#      size
# 410  2430
# 411  1395
# 412  1810
# 413   717
# 414  2170
# 415  3120
# 416  1870
# 417  2285
# 418  2783
# 419  2540

# %%
d=data.iloc[:,3:4]
d.tail(5)
# Out:
#      zip_code
# 415     98144
# 416     98136
# 417     98116
# 418     98199
# 419     98107

# %%
e=data.iloc[:,4:]
e.head(10)
# Out:
#      price
# 0   795000
# 1   915000
# 2   950000
# 3  1950000
# 4   950000
# 5   740000
# 6   460000
# 7  3150000
# 8   565000
# 9   699000

# %%
type(e)
# Out:
# pandas.core.frame.DataFrame

# %%
type(c)
# Out:
# pandas.core.frame.DataFrame

# %%
data.corr()
# Out:
#               beds     baths      size  zip_code     price
# beds      1.000000  0.657510  0.827190  0.075634  0.557502
# baths     0.657510  1.000000  0.658436  0.019039  0.582817
# size      0.827190  0.658436  1.000000  0.069872  0.776065
# zip_code  0.075634  0.019039  0.069872  1.000000 -0.048492
# price     0.557502  0.582817  0.776065 -0.048492  1.000000

# %%
#visualize the dataset when comparing no of bedrooms and price of the house
plt.scatter(a,e)
plt.title('Prices of houses based on no of bedrooms')
plt.xlabel('no of bedrooms')
plt.ylabel('price of house')
plt.show()

# %%
import sklearn
from sklearn.model_selection import train_test_split
atrain,atest,btrain,btest,ctrain,ctest,dtrain,dtest,etrain,etest=train_test_split(a,b,c,d,e,test_size=0.2)

# %%
data.shape
# Out:
# (420, 5)

# %%
atrain.shape
# Out:
# (336, 1)

# %%
atest.shape
# Out:
# (84, 1)

# %%
btrain.shape
# Out:
# (336, 1)

# %%
btest.shape
# Out:
# (84, 1)

# %%
etrain.shape
# Out:
# (336, 1)

# %%
etest.shape
# Out:
# (84, 1)

# %%
etrain
# Out:
#        price
# 397  2300000
# 411   725000
# 142   459000
# 101   550000
# 339   445000
# ..       ...
# 114   525000
# 18   1750000
# 337  1009975
# 268  1025000
# 254   852500
#
# [336 rows x 1 columns]

# %%
etest
# Out:
#        price
# 195   756500
# 40   1070000
# 115   630000
# 126  1495000
# 32    950000
# ..       ...
# 262   950000
# 52    800000
# 174   977000
# 401  1000000
# 144  1350000
#
# [84 rows x 1 columns]

# %%
ctest
# Out:
#      size
# 195  3400
# 40   1500
# 115  1910
# 126  3040
# 32   1550
# ..    ...
# 262  2780
# 52   2480
# 174  2080
# 401   376
# 144  1188
#
# [84 rows x 1 columns]

# %%
btrain
# Out:
#      baths
# 397    3.5
# 411    2.5
# 142    1.0
# 101    1.0
# 339    1.0
# ..     ...
# 114    2.0
# 18     2.5
# 337    2.5
# 268    2.5
# 254    2.5
#
# [336 rows x 1 columns]

# %% [markdown]
# # Implement Simple linear regression
# a.) Choose a feature(ex-square footage) as an independent variable(X) and house prices as the dependant variable(Y) b.) Implement simple linear regression model using sklearn to predict house prices based on the selected feature c.)Visualize the data and the regression line

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
#train the data
print("Training Started.......\n")
print()
lin_reg.fit(ctrain,etrain)
print('Training completed.....')
print()
#test the data
print('Testing invoked......\n')
epredict=lin_reg.predict(ctest)
print('Predicted price\n',epredict)
print('\nTesting is also completed....\n')
# Out:
# Training Started.......
#
#
# Training completed.....
#
# Testing invoked......
#
# Predicted price
#  [[1706294.59958098]
#  [ 809350.52624453]
#  [1002901.61575397]
#  [1536347.30147512]
#  [ 832954.31764812]
#  [ 360878.4895763 ]
#  [ 441131.38034851]
#  [2008423.12954694]
#  [1068992.23168403]
#  [ 700773.08578801]
#  [1479698.20210651]
#  [1120920.57277193]
#  [ 790467.49312166]
#  [ 667727.77782298]
#  [1129417.93767722]
#  [1357430.56263591]
#  [1212503.28341786]
#  [ 642707.75893518]
#  [1871521.13940611]
#  [1734619.14926529]
#  [1153965.88073695]
#  [ 818792.04280596]
#  [1177569.67214054]
#  [ 606357.92017365]
#  [ 611078.67845437]
#  [1309750.90400065]
#  [ 663007.01954227]
#  [1271984.83775491]
#  [1432490.61929932]
#  [ 568591.8539279 ]
#  [ 514303.13369964]
#  [ 516663.51284   ]
#  [ 592195.64533149]
#  [ 837675.07592884]
#  [ 387786.8117764 ]
#  [1508022.75179081]
#  [ 392507.57005711]
#  [ 443019.6836608 ]
#  [ 828233.5593674 ]
#  [ 455293.65519067]
#  [5298791.65120749]
#  [ 729097.63547232]
#  [1677970.04989667]
#  [ 807462.22293224]
#  [ 511942.75455928]
#  [1078433.74824546]
#  [1158686.63901767]
#  [ 510998.60290314]
#  [ 677169.29438442]
#  [ 629961.71157724]
#  [ 851837.35077099]
#  [ 889603.41701674]
#  [ 396756.25250976]
#  [1970657.06330119]
#  [1498581.23522938]
#  [ 563871.09564718]
#  [1391892.09808515]
#  [ 832954.31764812]
#  [1220056.49666701]
#  [1229498.01322844]
#  [ 835314.69678848]
#  [1059550.71512259]
#  [1338075.45368496]
#  [1309750.90400065]
#  [1253101.80463203]
#  [ 745620.28945483]
#  [ 994876.32667675]
#  [ 793772.02391816]
#  [1544372.59055234]
#  [ 777721.44576372]
#  [ 984018.5826311 ]
#  [ 460014.41347138]
#  [1168128.15557911]
#  [ 325000.72664285]
#  [ 691331.56922657]
#  [ 889603.41701674]
#  [1106758.29792977]
#  [ 573312.61220862]
#  [1188899.49201427]
#  [1413607.58617645]
#  [1271984.83775491]
#  [1083154.50652618]
#  [ 278737.29549181]
#  [ 662062.86788612]]
#
# Testing is also completed....

# %%
etrain
# Out:
#        price
# 397  2300000
# 411   725000
# 142   459000
# 101   550000
# 339   445000
# ..       ...
# 114   525000
# 18   1750000
# 337  1009975
# 268  1025000
# 254   852500
#
# [336 rows x 1 columns]

# %%
etest
# Out:
#        price
# 195   756500
# 40   1070000
# 115   630000
# 126  1495000
# 32    950000
# ..       ...
# 262   950000
# 52    800000
# 174   977000
# 401  1000000
# 144  1350000
#
# [84 rows x 1 columns]

# %%
diff=etest-epredict
diff
# Out:
#              price
# 195 -949794.599581
# 40   260649.473755
# 115 -372901.615754
# 126  -41347.301475
# 32   117045.682352
# ..             ...
# 262 -463607.586176
# 52  -471984.837755
# 174 -106154.506526
# 401  721262.704508
# 144  687937.132114
#
# [84 rows x 1 columns]

# %%
#Visualise the training dataset
plt.scatter(ctrain,etrain,color='yellow')
plt.plot(ctrain,lin_reg.predict(ctrain),color='blue')
plt.title('Prices according to squarefoot of the house(training dataset)')
plt.xlabel('sqft')
plt.ylabel('price')
plt.show()

# %%
#Visualise the test dataset
plt.scatter(ctest,etest,color='green')
plt.plot(ctest,lin_reg.predict(ctest),color='red')
plt.title('Prices according to squarefoot of the house(testing dataset)')
plt.xlabel('size')
plt.ylabel('price')
plt.show()

# %% [markdown]
# # Evaluate the Simple linear regression model
# a.)Use scikit learn to calculate the R-squared value to assess the goodness of fit b.)Interpret the R-squared value and discuss the model's performance

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

print('Mean Squared Error ; \t',mean_squared_error(etest,epredict))
print()
print('RMSE:\t',np.sqrt(mean_squared_error(etest,epredict)))
print()
print('Variance Score:\t',explained_variance_score(etest,epredict))

#Coefficient of determination- R_square
print()
print('R-Square:\t',r2_score(etest,epredict))
# Out:
# Mean Squared Error ; 	 262785465385.2974
#
# RMSE:	 512626.04828987905
#
# Variance Score:	 0.4893840876529799
#
# R-Square:	 0.48930110310439257

# %% [markdown]
# # Implement Multiple linear Regression
# 1.)Select multiple features (ex-squarefootage,number of bedrooms, number of bathrooms)as independendent variables(X) and house prices as the dependant variable(Y) 2.) Implement a multiple linear regression model using sci-kit learn to predict house prices based on the selected features

# %%
df=pd.read_csv('home_data.csv')
df.head()
# Out:
#    beds  baths  size  zip_code    price
# 0     3    2.5  2590     98144   795000
# 1     4    2.0  2240     98106   915000
# 2     4    3.0  2040     98107   950000
# 3     4    3.0  3800     98199  1950000
# 4     2    2.0  1042     98102   950000

# %%
df.isna().sum()
# Out:
# beds        0
# baths       0
# size        0
# zip_code    0
# price       0
# dtype: int64

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#    beds  baths  size  zip_code    price
# 0     3    2.5  2590     98144   795000
# 1     4    2.0  2240     98106   915000
# 2     4    3.0  2040     98107   950000
# 3     4    3.0  3800     98199  1950000
# 4     2    2.0  1042     98102   950000

# %%
x=df.iloc[:,:-1]
x.head()
# Out:
#    beds  baths  size  zip_code
# 0     3    2.5  2590     98144
# 1     4    2.0  2240     98106
# 2     4    3.0  2040     98107
# 3     4    3.0  3800     98199
# 4     2    2.0  1042     98102

# %%
y=data.iloc[:,-1:]
y.head()
# Out:
#      price
# 0   795000
# 1   915000
# 2   950000
# 3  1950000
# 4   950000

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
mul_reg=LinearRegression()
#train the model
mul_reg.fit(xtrain,ytrain)
print("Training completed")
print()
#test the model
ypred=mul_reg.predict(xtest)
print("Testing completed")
# Out:
# Training completed
#
# Testing completed

# %% [markdown]
# # Evaluate the Multiple linear Regression model
# Calculate MAE,MSE,RMSE to assess the model's accuracy

# %%
from sklearn.metrics import mean_squared_error,r2_score
print()
print('Mean Squared Error ; \t',mean_squared_error(ytest,ypred))
print()
print('RMSE: ', np.sqrt(mean_squared_error(ytest,ypred)))
print()
print('R-square: ',r2_score(ytest,ypred))
print()
# Out:
# Mean Squared Error ; 	 76696916482.0468
#
# RMSE:  276942.0814575618
#
# R-square:  0.6764019514855344
