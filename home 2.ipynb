# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %% [markdown]
# # Data preparation
# 1.) Load the dataset using pandas

# %%
data=pd.read_csv('home_data.csv')
data
# Out:
#      beds  baths  size  zip_code    price
# 0       3    2.5  2590     98144   795000
# 1       4    2.0  2240     98106   915000
# 2       4    3.0  2040     98107   950000
# 3       4    3.0  3800     98199  1950000
# 4       2    2.0  1042     98102   950000
# ..    ...    ...   ...       ...      ...
# 415     4    3.0  3120     98144  1670000
# 416     3    2.0  1870     98136   849000
# 417     4    3.5  2285     98116  1500000
# 418     3    2.5  2783     98199  1640000
# 419     4    2.0  2540     98107  1280000
#
# [420 rows x 5 columns]

# %% [markdown]
# # 2.)Explore and clean the data.Handle missing values and outliers

# %%
data.head()
# Out:
#    beds  baths  size  zip_code    price
# 0     3    2.5  2590     98144   795000
# 1     4    2.0  2240     98106   915000
# 2     4    3.0  2040     98107   950000
# 3     4    3.0  3800     98199  1950000
# 4     2    2.0  1042     98102   950000

# %%
data.tail()
# Out:
#      beds  baths  size  zip_code    price
# 415     4    3.0  3120     98144  1670000
# 416     3    2.0  1870     98136   849000
# 417     4    3.5  2285     98116  1500000
# 418     3    2.5  2783     98199  1640000
# 419     4    2.0  2540     98107  1280000

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'beds'}>,
#         <Axes: title={'center': 'baths'}>],
#        [<Axes: title={'center': 'size'}>,
#         <Axes: title={'center': 'zip_code'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: >]], dtype=object)

# %%
data.describe()
# Out:
#              beds       baths          size      zip_code         price
# count  420.000000  420.000000    420.000000    420.000000  4.200000e+02
# mean     3.000000    2.251190   1841.864286  98125.371429  9.694295e+05
# std      1.355621    1.034892   1008.702748     24.929976  5.763080e+05
# min      1.000000    0.500000    376.000000  98101.000000  1.594880e+05
# 25%      2.000000    1.500000   1120.000000  98107.000000  6.150000e+05
# 50%      3.000000    2.000000   1695.000000  98117.000000  8.450000e+05
# 75%      4.000000    3.000000   2370.000000  98133.000000  1.148500e+06
# max     15.000000    8.500000  11010.000000  98199.000000  5.495000e+06

# %%
data.head(10)
# Out:
#    beds  baths  size  zip_code    price
# 0     3    2.5  2590     98144   795000
# 1     4    2.0  2240     98106   915000
# 2     4    3.0  2040     98107   950000
# 3     4    3.0  3800     98199  1950000
# 4     2    2.0  1042     98102   950000
# 5     2    2.0  1190     98107   740000
# 6     1    1.0   670     98133   460000
# 7     5    3.5  4510     98105  3150000
# 8     3    2.5  1520     98108   565000
# 9     4    2.0  2340     98178   699000

# %%
data.isnull().sum()
# Out:
# beds        0
# baths       0
# size        0
# zip_code    0
# price       0
# dtype: int64

# %% [markdown]
# # 3.) Split the dataset into training and testing sets

# %%
x=data.iloc[:,:-1]
x.head(20)
# Out:
#     beds  baths  size  zip_code
# 0      3    2.5  2590     98144
# 1      4    2.0  2240     98106
# 2      4    3.0  2040     98107
# 3      4    3.0  3800     98199
# 4      2    2.0  1042     98102
# 5      2    2.0  1190     98107
# 6      1    1.0   670     98133
# 7      5    3.5  4510     98105
# 8      3    2.5  1520     98108
# 9      4    2.0  2340     98178
# 10     3    2.0  1320     98103
# 11     3    2.0  1800     98177
# 12     3    2.5  2490     98103
# 13     4    3.0  2650     98115
# 14     5    1.5  2560     98199
# 15     2    1.5   900     98133
# 16     3    3.5  1360     98103
# 17     1    1.0   550     98122
# 18     3    2.5  2974     98119
# 19     4    3.5  1989     98117

# %%
y=data.iloc[:,-1:]
y.head(20)
# Out:
#       price
# 0    795000
# 1    915000
# 2    950000
# 3   1950000
# 4    950000
# 5    740000
# 6    460000
# 7   3150000
# 8    565000
# 9    699000
# 10   899000
# 11  1050000
# 12   935625
# 13  1511000
# 14  1330000
# 15   549755
# 16   700000
# 17   330000
# 18  1750000
# 19   980000

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
xtrain,xtest,ytrain,ytest=home_test_split(x,y,test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 xtrain,xtest,ytrain,ytest=home_test_split(x,y,test_size=0.2)
#
# NameError: name 'home_test_split' is not defined
