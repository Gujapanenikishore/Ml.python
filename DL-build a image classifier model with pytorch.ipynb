# %%
pip install torch torchvision
# Out:
# Requirement already satisfied: torch in c:\users\kisho\anaconda3\lib\site-packages (2.1.0)
# Collecting torchvision
#   Downloading torchvision-0.16.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in c:\users\kisho\anaconda3\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\kisho\anaconda3\lib\site-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in c:\users\kisho\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\kisho\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\kisho\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\kisho\anaconda3\lib\site-packages (from torch) (2023.3.0)
# Requirement already satisfied: numpy in c:\users\kisho\anaconda3\lib\site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: requests in c:\users\kisho\anaconda3\lib\site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\kisho\anaconda3\lib\site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kisho\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kisho\anaconda3\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kisho\anaconda3\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kisho\anaconda3\lib\site-packages (from requests->torchvision) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kisho\anaconda3\lib\site-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\kisho\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Downloading torchvision-0.16.0-cp311-cp311-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.3 MB 186.2 kB/s eta 0:00:07
#    - -------------------------------------- 0.0/1.3 MB 196.9 kB/s eta 0:00:07
#    -- ------------------------------------- 0.1/1.3 MB 327.3 kB/s eta 0:00:04
#    --- ------------------------------------ 0.1/1.3 MB 364.4 kB/s eta 0:00:04
#    ---- ----------------------------------- 0.1/1.3 MB 448.2 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.2/1.3 MB 446.5 kB/s eta 0:00:03
#    ------ --------------------------------- 0.2/1.3 MB 497.6 kB/s eta 0:00:03
#    ------ --------------------------------- 0.2/1.3 MB 497.6 kB/s eta 0:00:03
#    -------- ------------------------------- 0.3/1.3 MB 548.9 kB/s eta 0:00:02
#    -------- ------------------------------- 0.3/1.3 MB 548.9 kB/s eta 0:00:02
#    ---------- ----------------------------- 0.3/1.3 MB 566.9 kB/s eta 0:00:02
#    ---------- ----------------------------- 0.3/1.3 MB 566.9 kB/s eta 0:00:02
#    ------------- -------------------------- 0.4/1.3 MB 582.6 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.3 MB 655.4 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.3 MB 655.4 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.3 MB 655.4 kB/s eta 0:00:02
#    ------------------ --------------------- 0.6/1.3 MB 643.6 kB/s eta 0:00:02
#    -------------------- ------------------- 0.6/1.3 MB 700.8 kB/s eta 0:00:01
#    -------------------- ------------------- 0.6/1.3 MB 700.8 kB/s eta 0:00:01
#    ----------------------- ---------------- 0.7/1.3 MB 705.5 kB/s eta 0:00:01
#    ------------------------ --------------- 0.8/1.3 MB 711.4 kB/s eta 0:00:01
#    --------------------------- ------------ 0.9/1.3 MB 774.9 kB/s eta 0:00:01
#    --------------------------- ------------ 0.9/1.3 MB 774.9 kB/s eta 0:00:01
#    -------------------------------- ------- 1.0/1.3 MB 820.9 kB/s eta 0:00:01
#    --------------------------------- ------ 1.1/1.3 MB 815.4 kB/s eta 0:00:01
#    ------------------------------------ --- 1.1/1.3 MB 855.9 kB/s eta 0:00:01
#    ---------------------------------------  1.3/1.3 MB 918.6 kB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 891.0 kB/s eta 0:00:00
# Installing collected packages: torchvision
# Successfully installed torchvision-0.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define a simple CNN model
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=10):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(32 * 8 * 8, 128)
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 32 * 8 * 8)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Hyperparameters
num_epochs = 10
batch_size = 32
learning_rate = 0.001

# Load CIFAR-10 dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# Initialize the model, loss function, and optimizer
model = SimpleCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Training the model
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 100 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}')

# Test the model
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print(f'Test Accuracy of the model on the 10000 test images: {100 * correct / total}%')

# Save the model
torch.save(model.state_dict(), 'simple_cnn_model.pth')
